# %% [markdown]
# # Setup

# %% [markdown]
# Link: https://huggingface.co/learn/llm-course/chapter0/1

# %% [markdown]
# ## Using a Python virtual environment

# %% [markdown]
# ```bash
# mkdir transformers-course
# cd transformers-course
#
# sudo apt install python3-venv
# python3 -m venv .env
# source .env/bin/activate
#
# which python
#
# pip install --upgrade pip
# pip config set global.extra-index-url https://download.pytorch.org/whl/cpu
# pip install "transformers[sentencepiece]" torch
#
# pip install ipywidgets jupyterlab
# jupyter lab
# ```

# %% [markdown]
# ## Exiting JupyterLab
# 1. Close the Browser
# 2. CTRL+C and confirm to exit the `jupyter lab` command

# %% [markdown]
# ## Exiting the virtual environment
# ```bash
# deactivate
# ```

# %% [markdown]
# ## My notes

# %% [markdown]
# This is required to make pip install cpu-only versions of torch etc. for running inside a virtual machine
# ```bash
# pip config set global.extra-index-url https://download.pytorch.org/whl/cpu
# ```
